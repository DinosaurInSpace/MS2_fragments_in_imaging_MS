# %%
from pyimzml.ImzMLParser import ImzMLParser
from pyimzml.ImzMLParser import getionimage
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import json

# %%
def hotspot_fill_2(img, per):
    q = np.quantile(img, per)
    img[img > q] = q
    return img

# %%
f = ImzMLParser('/Users/dis/Desktop/whole_body_word_2_vec/datasets/wb xenograft in situ metabolomics test - rms_corrected.imzML')

# %%
f

# %%
ATP = [508.0030, 410.0262, 216.0271, 136.0618]

# %%
Arg = [175.1189, 158.1163, 130.0983, 70.0652, 60.0556]

# %%
GSSG = [613.1592, 595.1487, 538.1272, 484.1167, 409.0846, 355.0741, 231.0434]
GSH = [308.0911]
ADP = [428.0367, 348.0704, 136.0618]
Glutamate = [] # not assigned in this dataset.
maltotriose = [527.1582, 365.1051, 347.0954]
Stearidonic_acid = [259.2057, 193.9713, 163.1482, 135.1169]
SAM = [385.1288, 250.0744, 136.0618, 134.0271]

# %%
target_name = 'Stearidonic_acid'
target = Stearidonic_acid
n = 3
title = target_name + "_" + str(n)
path = "/Users/dis/PycharmProjects/word2vec/" + title

# %%
mz = target[n]
tol_ppm = mz * 3 / 1000000
x = getionimage(f, mz, tol=tol_ppm, z=1, reduce_func=sum)
x = hotspot_fill_2(x, 0.99)

#%matplotlib notebook
plt.imshow(x, cmap='viridis', interpolation ='nearest')
plt.savefig(path, bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %pwd
# Out:
# '/Users/dis/PycharmProjects/IMS_test'

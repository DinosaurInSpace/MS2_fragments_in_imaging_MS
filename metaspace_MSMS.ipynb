# %%
# Will reload modeules after this when they change!
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

# %%
# !pwd
# Out:
# /Users/dis/PycharmProjects/word2vec

# %%
database_in_path = '/Users/dis/PycharmProjects/core_metabolome/core_metabolome_v3.pickle
database_out_path = 'databases/'
gnps_dl_path = '/Users/dis/PycharmProjects/word2vec/ALL_GNPS.json'
hmdb_expt_path = 'hmdb_pos_exptl_df.pickle'
hmdb_theo_path = 'hmdb_pos_theo_df.pickle'
mona_dl_path = 'mona_2020_Apr_15.pickle'

# %%
# Parses HMDB xml download, only necessary when database is updated or downloaded again.
# !python hmdb_parser.py --input /Users/dis/Desktop/hmdb_LCMS/ --output databases/ --polarity both
# Out:
# HMDB parsing complete!

# %%
# Parses HMDB xml download, only necessary when database is updated or downloaded again.
# !python query_mona.py --input /Users/dis/PycharmProjects/core_metabolome/core_metabolome_v3.pickle --output databases/ --polarity negative
# Out:
# here
# InChI=1S/C4H4N2/c1-2-5-4-6-3-1/h1-4H
# 1
#
# InChI=1S/H2O3S/c1-4(2)3/h(H2,1,2,3)
# 2
#
# -1
# InChI=1S/C4H4O2/c5-4-2-1-3-6-4/h1,3H,2H2
# 3
#
# InChI=1S/C5H8O/c1-3-4-5(2)6/h3-4H,1-2H3/b4-3+
# 4
#
# InChI=1S/C5H8O/c1-5(2)3-4-6/h3-4H,1-2H3
# 5
#
# InChI=1S/C3H3NS/c1-2-5-3-4-1/h1-3H
# 6
#
# InChI=1S/C4H7NO/c6-4-2-1-3-5-4/h1-3H2,(H,5,6)
# 7
#
# InChI=1S/C4H6O2/c5-4-2-1-3-6-4/h1-3H2
# 8
#
# InChI=1S/C4H6O2/c1-2-3-4(5)6/h2-3H,1H3,(H,5,6)/b3-2-
# 9
#
# InChI=1S/C4H6O2/c1-3(5)4(2)6/h1-2H3
# 10
#
# InChI=1S/C4H6O2/c1-2-3-4(5)6/h2-3H,1H3,(H,5,6)/b3-2+
# 11
#
# -1
# -2
# -3
# -4
# InChI=1S/C5H10O/c1-5(2)3-4-6/h4-5H,3H2,1-2H3
# 12
#
# InChI=1S/C4H9NO/c1-4(2)3-5-6/h3-4,6H,1-2H3
# 13
#
# InChI=1S/C3H4O3/c1-2(4)3(5)6/h1H3,(H,5,6)
# 14
#
# -1
# -2
# -3
# -4
# -5
# -6
# InChI=1S/C3H4O3/c4-2-1-3(5)6/h2H,1H2,(H,5,6)
# 15
#
# InChI=1S/C4H8O2/c1-3(2)4(5)6/h3H,1-2H3,(H,5,6)
# 16
#
# -1
# -2
# -3
# -4
# InChI=1S/C4H8O2/c1-2-3-4(5)6/h2-3H2,1H3,(H,5,6)
# 17
#
# -1
# -2
# -3
# -4
# -5
# -6
# ...

# %%
# !python parse_reference_spectra.py(database_in_path,
                                   database_out_path,
                                   gnps_dl_path,
                                   hmdb_expt_path,
                                   hmdb_theo_path,
                                   mona_dl_path
                                  )
